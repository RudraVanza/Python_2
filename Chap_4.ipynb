# %% [markdown]
# # Feture Construction
#
# 1> Adding New Column in Data Fram

# %%
# 1> Adding New Column in Data Fram
import pandas as pd
length = [18,20,10,12,18,11]
width = [20,20,10,11,19,20]
data = {"length":length,"width":width}
df = pd.DataFrame(data)
df
df["area"] = df["length"]*df["width"] #For Adding New column
df

# %%
df= pd.read_csv("car data.csv")
df
df["car_age"] = 2025 - df["Year"] # For Adding car_age column
df

# %% [markdown]
# 2> Convert Categorical Data into numeric data

# %%
age = [18,20,23,19,18,22]
city = ["A","B","B","A","C","B"]
data = {"age":age,"city":city}
df = pd.DataFrame(data)
df
df = pd.get_dummies(data=df) #To Get Dummi Data , Converting Numeric Data,, drop_first=True => For 
df

# %%
df = pd.read_csv("car data.csv")
df = df.drop("Car_Name",axis=1) # To Remove Car_Name Column
df = pd.get_dummies(data=df) # To Get Dummies Of All Column
df

# %% [markdown]
# 3> Convert Numeric Data Into Categorical Data

# %%
import numpy as np
df["Kms_Driven"] = np.where(df["Kms_Driven"]>40000,"High",np.where(df["Kms_Driven"]<30000,"Low","Medium"))
df["Selling_Price"] = np.where(df["Selling_Price"]>9,"Premium",np.where(df["Selling_Price"]<5,"Basic","Moderate"))
df

# %% [markdown]
# # Simple Linear Regression
# Steps :-
#     1> Load Data Set
#     2> Check Null Value
#     3> Shape Of Data Frame
#     4> Define x & y
#     5> Print Shape OF x & y
#     6> Split Data Into Train & Test
#     7> Model Selection
#     8> Find m & c
#     9> Find Error

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Step 1 :- Load Data Set
df = pd.read_csv("Book1.csv")
df

#Step 2 :- Check Null Value
df.isna().sum()

# Step 3 :- Shape Of Data Frame
df.shape

# Step 4 :- Define x & y
x = df[['cgpa']]
x
y = df[['package']]
y

# Step 5 :-  Print Shape OF x & y
x.shape
y.shape

# Step 6 :- Split Data Into Train & Test
# from sklearn.model_selection import train_test_split => For Step 6
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)
x_train.shape #(160,1)
x_test.shape #(40,1)
y_train.shape #(160,1)
y_test.shape #(40,1)
''
''
# Step 7 :- Model Selection
# from sklearn.linear_model import LinearRegression => for Step 7
lr = LinearRegression()
lr.fit(x_train,y_train) # To Train Model

# Step 8 :- Find m & c   
m = lr.coef_ # Find m for y = mx + c
print("Value Of m :- ",m)
c = lr.intercept_ # Find c for y = mx + c , intercept_ = Slope
print("Value Of c :- ",c)

# y1 = lr.predict([[7]]) # For Show For & CGPA
# print("Packege of 7 CGPA :- ",y1)

# Step 9 :- Find Error   
# For Find ERROR in Model :- from sklearn.metrics import mean_squared_error
print(y_test)
y_pred = lr.predict(x_test) # To Find Predicted Packege Of x_test
print(y_pred)
print("mean_squared_error(MSE) :- ",mean_squared_error(y_test,y_pred)) # mean_squared_error(y_test,y_pred) => To find mean_squre_error

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


df = pd.read_csv("olympic100.csv")
df

print(df.isna().sum())

print(df.shape)

x = df[['year']]
print(x)
y = df[['time']]
print(y)

print("Shape of x :- ",x.shape)
print("Shape of y :- ",y.shape)

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2,random_state=2)
print("X_Test :- ",x_test.shape)
print("X_Train :- ",x_train.shape)
print("Y_Test :- ",y_test.shape)
print("Y_Train :- ",y_train.shape)

lr = LinearRegression()
lr.fit(x_train,y_train)

m = lr.coef_
print(m)
c = lr.intercept_
print(c)

y1 = lr.predict([[2025]])
print("Y1 :- ",y1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


df = pd.read_csv("heights_weights.csv")
df

print(df.isna().sum())

print(df.shape)

x = df[['Height']]
print(x)
y = df[['Weight']]
print(y)

print("Shape of x :- ",x.shape)
print("Shape of y :- ",y.shape)

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2,random_state=2)
print("X_Test :- ",x_test.shape)
print("X_Train :- ",x_train.shape)
print("Y_Test :- ",y_test.shape)
print("Y_Train :- ",y_train.shape)

lr = LinearRegression()
lr.fit(x_train,y_train)

m = lr.coef_
print(m)
c = lr.intercept_
print(c)

y1 = lr.predict([[80]])
print("Y1 :- ",y1)

print(y_test)
y_pred = lr.predict(x_test) # To Find Predicted Packege Of x_test
print(y_pred)
print("mean_squared_error(MSE) :- ",mean_squared_error(y_test,y_pred))

# %%
# HW :- tipe.csv ma total_bill parthi , tip find karvani

# %% [markdown]
# # Multiple Linear Regression
# Formula :- " y = m1x1 + m2x2 + m3x3 + .... + c "
# Steps:-
#     1> Load Data
#     2> Print Shape
#     3> Check null Value
#     4> Data Preprocessing
#     5> Data Preparation
#     6> Define x & y
#     7> Split data into Train & Test
#     8> Model Selection
#     9> Find m & c
#     10> Find Error

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score , mean_absolute_error

# Step 1> Load Data  
df = pd.read_csv("car data.csv")
df

# Step 2> Print Shape   
print(df.shape)

# Step 3> Check null Value
print(df.isna().sum())

# Step 4> Data Preprocessing 
df["Age"] = 2025 - df["Year"]  # To get age of car
df
df = df.drop("Year",axis=1) # to drop year column
df = df.drop("Car_Name",axis=1) # to drop Car_Name column

# Step 5> Data Preparation 
df = pd.get_dummies(data=df,drop_first=True) #To get dummy columns and drop first dummy column
df

df.columns  # To get all column name from data frame

# Step 6> Define x & y
y = df["Selling_Price"]
print(y)
x = df.drop("Selling_Price",axis=1)
print(x)
print("Shape of x :- ",x.shape)
print("Shape of y :- ",y.shape)

# Step 7> Split data into Train & Test
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2,random_state=2)
print("X_Train :- ",x_train.shape)
print("X_Test :- ",x_test.shape)
print("Y_Train :- ",y_train.shape)
print("Y_Test :- ",y_test.shape)

# Step 8> Model Selection
lr = LinearRegression()
lr.fit(x_train,y_train)

# Step 9> Find m & c
m = lr.coef_
print("value of m :- ",m)
c = lr.intercept_
print("Value of c :- ",c) 

# Present price 5.5, Kms_Driven = 100000, Owner = 0, Year = 10, Fuel_Type = Petrol , Seller_Type = indivisual , Transmission = menual
y1 = lr.predict([[5.5,100000,0,10,0,1,0,1]])
print("Predicted Price is (y1) : ",y1)

# Present price = 7 , Kms_Driven = 90000, Owner = 0, Year = 5, Fuel_Type = CNG , Seller_Type = indivisual , Transmission = Auto
y2 = lr.predict([[7,90000,0,5,0,0,1,0]])
print("Predicted Price is (y2) : ",y2)

# Step 10> Find Error
y_pred = lr.predict(x_test) # To Find Predicted Price Of Car 
print("MSE :- ",mean_squared_error(y_test,y_pred))
print("RMSE :- ",mean_squared_error(y_test,y_pred)**(0.5))
print("MAE :- ",mean_absolute_error(y_test,y_pred))
print("R2_score :- ",r2_score(y_test,y_pred))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score , mean_absolute_error

# Step 1> Load Data  
df = pd.read_csv("advertising.csv")
df

# Step 2> Print Shape   
print(df.shape)

# Step 3> Check null Value
print(df.isna().sum())

df.columns  # To get all column name from data frame

# Step 6> Define x & y
y = df["Sales"]
print(y)
x = df.drop("Sales",axis=1)
print(x)
print("Shape of x :- ",x.shape)
print("Shape of y :- ",y.shape)

# Step 7> Split data into Train & Test
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2,random_state=1)
print("X_Train :- ",x_train.shape)
print("X_Test :- ",x_test.shape)
print("Y_Train :- ",y_train.shape)
print("Y_Test :- ",y_test.shape)

# Step 8> Model Selection
lr = LinearRegression()
lr.fit(x_train,y_train)

# Step 9> Find m & c
m = lr.coef_
print("value of m :- ",m)
c = lr.intercept_
print("Value of c :- ",c) 

#TV = 230.1 , Radio = 37.8 , Newspaper = 69.2 ,Sales = ?
y1 = lr.predict([[230.1,37.8,69.2]])
print("y1 :- ",y1)
# Step 10> Find Error
y_pred = lr.predict(x_test) # To Find Predicted Price Of Car 
print("MSE :- ",mean_squared_error(y_test,y_pred))
print("RMSE :- ",mean_squared_error(y_test,y_pred)**(0.5))
print("MAE :- ",mean_absolute_error(y_test,y_pred))
print("R2_score :- ",r2_score(y_test,y_pred))

# %%
# QB 205
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score , mean_absolute_error

# Step 1> Load Data  
df = pd.read_csv("FuelConsumptionCo2.csv")
df

# Step 2> Print Shape   
print(df.shape)

# Step 3> Check null Value
print(df.isna().sum())

df.columns  # To get all column name from data frame

# Step 6> Define x & y
df = pd.get_dummies(data=df,drop_first=True)
df
y = df["CO2EMISSIONS"]
x = df.drop("CO2EMISSIONS", axis=1)
print("Shape of x :- ",x.shape)
print("Shape of y :- ",y.shape)


# Step 7> Split data into Train & Test
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2,random_state=1)
print("X_Train :- ",x_train.shape)
print("X_Test :- ",x_test.shape)
print("Y_Train :- ",y_train.shape)
print("Y_Test :- ",y_test.shape) 
print(df)
# Step 8> Model Selection
lr = LinearRegression()
lr.fit(x_train,y_train)

# # Step 9> Find m & c
# m = lr.coef_
# print("value of m :- ",m)
# c = lr.intercept_
# print("Value of c :- ",c) 

# #TV = 230.1 , Radio = 37.8 , Newspaper = 69.2 ,Sales = ?
# y1 = lr.predict([[230.1,37.8,69.2]])
# print("y1 :- ",y1)
# # Step 10> Find Error
y_pred = lr.predict(x_test) # To Find Predicted Price Of Car 
print("MSE :- ",mean_squared_error(y_test,y_pred))
print("RMSE :- ",mean_squared_error(y_test,y_pred)**(0.5))
print("MAE :- ",mean_absolute_error(y_test,y_pred))
print("R2_score :- ",r2_score(y_test,y_pred))

# %%
# 1> Add new column "Total Marks" 
# 2> New Column "Grade" 85<A , 75<B , 65<c , 50<d , 35<e , 35>f 
# 3> Build Simple linear regression model and predict total marks based on test 1 marks
# 4> Also find msc , r2 score , take value of random state=42 
df = pd.read_csv("Marksheet.csv")
# 1>
df["Total Marks"] = df["TEST-1 MARKS"]+df["TEST-2 MARKS"]+df["TEST-3 MARKS"]+df["TEST-4 MARKS"]
# 2>
df["Grade"] = np.where(df["Total Marks"]>=85,"A", np.where(df["Total Marks"]>=75,"B", np.where(df["Total Marks"]>=65,"C", np.where(df["Total Marks"]>=50,"D", np.where(df["Total Marks"]>=35,"E","F" )))))
# 3>
print(df.isna().sum())
print(df.shape)
x = df[["TEST-1 MARKS"]]
print(x)
y = df[["Total Marks"]]
print(y)
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2,random_state=42)
lr = LinearRegression()
lr.fit(x_train,y_train)
m = lr.coef_
print(m)
c = lr.intercept_
print(c)
y_pred = lr.predict(x_test) # To Find Predicted Packege Of x_test
print(y_pred)
print("mean_squared_error(MSE) :- ",mean_squared_error(y_test,y_pred))
print("R2_Score :- ",r2_score(y_test,y_pred))

# %% [markdown]
# # Polynomial Regression
# Formula :- y = c + m1x^0 + m2x^1 + m3x^2 + ...

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures 
df = pd.read_csv("polylinearregression.csv")
x = df[["Temperature"]]
y = df[["Pressure"]]
print(x)
print(y)

plt.plot(x,y)
plt.scatter(x,y)
plt.show()

poly = PolynomialFeatures(degree=3)
x_poly = poly.fit_transform(x)
print(x_poly)

lr = LinearRegression()
lr.fit(x_poly,y)

m = lr.coef_
print("m :- ",m)
c = lr.intercept_
print("c :- ",c)

X_t = poly.fit_transform([[30]])
print("X_t :- ",X_t)

y1 = lr.predict(X_t)
print("Y1 :- ",y1)

# %%
#198> Predict salary based on job position of 6.5 using polynomial regression  with a degree of 3 and scikit learn library for the given 'Position_Salaries.csv' dataset.  (Don't split data for training/testing)

df = pd.read_csv('Position_Salaries.csv')
df
x = df[["Level"]]
y = df[["Salary"]]
print(x)
print(y)

poly = PolynomialFeatures(degree=3)
x_poly = poly.fit_transform(x)
print(x_poly)

lr = LinearRegression()
lr.fit(x_poly,y)
m = lr.coef_
print("m :- ",m)
c = lr.intercept_ 
print("c :- ",c)

x1 = poly.fit_transform([[6.5]])
print("x1 :- ",x1)

y_pred = lr.predict(x1)
print(y_pred)

# %%
#199>  For x = np.arange(0, 30) and y = np.array([3, 4, 5, 7, 10, 8, 9, 10, 10, 23, 27, 44, 50, 63, 67, 60, 62, 70, 75, 88, 81, 87, 95, 100, 108,135, 151, 160, 169, 179]), apply polynomial regression using scikit learn library and calculate  R squared, coeficient and intercept. Predict the y values for x = np.arange(5). (Don't split data for training/testing)
import numpy as np
x = np.arange(0, 30)
y = np.array([3, 4, 5, 7, 10, 8, 9, 10, 10, 23, 27, 44, 50, 63, 67, 60, 62, 70, 75, 88, 81, 87, 95, 100, 108,135, 151, 160, 169, 179])
x = x.reshape(-1,1)


poly = PolynomialFeatures(degree=3)
x_poly = poly.fit_transform(x)
x_poly 

lr = LinearRegression()
lr.fit(x_poly,y)

y1 = np.arange(5)
y_pred = lr.predict(poly.fit_transform(y1.reshape(-1,1)))
y_pred
